# %% [markdown]
# # Getting all available Swiss petrol stations using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import json
import folium
import requests
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# u:\Lektionen\WPM\spatial_data_analysis\01_Python_Basic_GIS_Functionality\Challenge

# %% [markdown]
# ## Overpass turbo query to get available petrol stations

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["amenity"="fuel"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to .json file
with open('petrol_stations.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = pd.json_normalize(data)
df.head()
# Out:
#    type       id        lat       lon tags.amenity  \
# 0  node   734402  46.690599  7.668189         fuel
# 1  node  1228781  46.878598  7.542326         fuel
# 2  node  5702030  46.680546  7.827412         fuel
# 3  node  5702071  46.683415  7.844559         fuel
# 4  node  8082505  46.683817  7.664427         fuel
#
#                                           tags.fixme tags.name tags.operator  \
# 0  Please check name and brand. Agip becomes Eni....      Agip          Agip
# 1                                                NaN       NaN            BP
# 2                                                NaN    Migrol           NaN
# 3                                                NaN      Avia          Avia
# 4                                                NaN       NaN           NaN
#
#   tags.brand tags.fuel:diesel  ... tags.fuel:octane_87  \
# 0        NaN              NaN  ...                 NaN
# 1         BP              yes  ...                 NaN
# 2        NaN              NaN  ...                 NaN
# 3       Avia              NaN  ...                 NaN
# 4        NaN              NaN  ...                 NaN
#
#   tags.fuel:Shell_V-Power tags.payment:post_finance tags.covered  \
# 0                     NaN                       NaN          NaN
# 1                     NaN                       NaN          NaN
# 2                     NaN                       NaN          NaN
# 3                     NaN                       NaN          NaN
# 4                     NaN                       NaN          NaN
#
#   tags.payment:girocard tags.payment:vpay tags.fuel:diesel_plus  \
# 0                   NaN               NaN                   NaN
# 1                   NaN               NaN                   NaN
# 2                   NaN               NaN                   NaN
# 3                   NaN               NaN                   NaN
# 4                   NaN               NaN                   NaN
#
#   tags.construction tags.dog tags.payment:hubrol_card
# 0               NaN      NaN                      NaN
# 1               NaN      NaN                      NaN
# 2               NaN      NaN                      NaN
# 3               NaN      NaN                      NaN
# 4               NaN      NaN                      NaN
#
# [5 rows x 191 columns]

# %% [markdown]
# ## Save data frame to a .csv file

# %%
# Write data frame to .csv - file
df.to_csv('petrol-stations.csv', index=False, sep=";", encoding='utf-8')

# %% [markdown]
# ## Use a pivot table to count the number of petrol stations per operator

# %%
# Create pivot table
tab = pd.pivot_table(df[['id', 'tags.name']], 
                       values=['id'], 
                       index=['tags.name'],
                       aggfunc='count')

# Sort pivot table
tab_sorted = tab.sort_values(by=['id'], ascending=False)
tab_sorted
# Out:
#                          id
# tags.name
# Avia                    162
# Agrola                  148
# BP                      110
# Tamoil                   97
# Shell                    77
# ...                     ...
# Garage du Clos            1
# Garage du Gros-de-Vaud    1
# Garage du Nord            1
# Garage du Port            1
# villoel                   1
#
# [803 rows x 1 columns]

# %% [markdown]
# ## Plot petrol stations on map

# %%
# Subset of petrol stations by brand
locations = df[["lat", 
                "lon", 
                "tags.brand", 
                "tags.shop"]].loc[df["tags.brand"].isin(['Migrol', 
                                                         'Agip', 
                                                         'Shell'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand tags.shop
# 8   47.686119  8.621418      Shell       NaN
# 19  47.495696  8.712981      Shell       NaN
# 23  47.381593  8.509545      Shell       NaN
# 28  47.381110  8.492148     Migrol       NaN
# 32  47.337432  8.530242      Shell       NaN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2512c38deeda873ac8389824d2ee455b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2512c38deeda873ac8389824d2ee455b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2512c38deeda873ac8389824d2ee455b = L.map(
#                 &quot;map_2512c38deeda873ac8389824d2ee455b&quot;,
#                 {
#                     center: [47.0727126117302, 8.13279277536657],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2512c38deeda873ac8389824d2ee455b);
#
#
#
#
#
#             var tile_layer_2f5825f9379708696a80ff20bd10f49c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2512c38deeda873ac8389824d2ee455b);
#
#
#             var marker_6c6731aa82d831833022c2c8fcd39ac4 = L.marker(
#                 [47.686119, 8.621418],
#                 {}
#             ).addTo(map_2512c38deeda873ac8389824d2ee455b);
#
#
#         var popup_98570c2273f8fb9d243c3c7906b15796 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c28962db16146d0fc0b554c3753e9c10 = $(`&lt;div id=&quot;html_c28962db16146d0fc0b554c3753e9c10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_98570c2273f8fb9d243c3c7906b15796.setContent(html_c28962db16146d0fc0b554c3753e9c10);
#
#
#
#         marker_6c6731aa82d831833022c2c8fcd39ac4.bindPopup(popup_98570c2273f8fb9d243c3c7906b15796)
#         ;
#
#
#
#
#             var marker_cbe2e176db5cb9dfe5f9894857f2d74d = L.marker(
#                 [47.4956958, 8.7129812],
#                 {}
#             ).addTo(map_2512c38deeda873ac8389824d2ee455b);
#
#
#         var popup_c19e1934b8ff3f68dea46af6561603b0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ddb11a98c26c16a86dac02777f97e301 = $(`&lt;div id=&quot;html_ddb11a98c26c16a86dac02777f97e301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_c19e1934b8ff3f68dea46af6561603b0.setContent(html_ddb11a98c26c16a86dac02777f97e301);
#
#
#
#         marker_cbe2e176db5cb9dfe5f9894857f2d74d.bindPopup(popup_c19e1934b8ff3f68dea46af6561603b0)
#         ;
#
#
#
#
#             var marker_062ed8a82b395539f4933740698de914 = L.marker(
#                 [47.3815928, 8.5095448],
#                 {}
#             ).addTo(map_2512c38deeda873ac8389824d2ee455b);
#
#
#         var popup_9c819985a3201ef862f557204b940165 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83eef27892fc0a6c458514481e1b6da7 = $(`&lt;div id=&quot;html_83eef27892fc0a6c458514481e1b6da7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_9c819985a3201ef862f557204b940165.setContent(html_83eef27892fc0a6c458514481e1b6da7);
#
#
#
#         marker_062ed8a82b395539f4933740698de914.bindPopup(popup_9c819985a3201ef862f557204b940165)
#         ;
#
#
#
#
#             var marker_cfec0587c7274b7e9777c6ca46ae3fd3 = L.marker(
#                 [47.3811098, 8.4921479],
#                 {}
#             ).addTo(map_2512c38deeda873ac8389824d2ee455b);
#
#
#         var popup_312dbfacc8acb1836e5c6ed652571b5e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_824ccaca7ca34e695f043459a7e6c44f = $(`&lt;div id=&quot;html_824ccaca7ca34e695f043459a7e6c44f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migrol&lt;/div&gt;`)[0];
#                 popup_312dbfacc8acb1836e5c6ed652571b5e.setContent(html_824ccaca7ca34e695f043459a7e6c44f);
#
#
#
#         marker_cfec0587c7274b7e9777c6ca46ae3fd3.bindPopup(popup_312dbfacc8acb1836e5c6ed652571b5e)
#         ;
#
#
#
#
#             var marker_e21660f21e2f700b61f18a9a86169999 = L.marker(
#                 [47.3374315, 8.5302419],
#                 {}
#             ).addTo(map_2512c38deeda873ac8389824d2ee455b);
#
#
#         var popup_fcb21f9f749508d7da7825dd528a437c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_646450773e443d2fdac6d3eb62c0d66b = $(`&lt;div id=&quot;html_646450773e443d2fdac6d3eb62c0d66b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_fcb21f9f749508d7da7825dd528a437c.setContent(html_646450773e443d2fdac6d3eb62c0d66b);
#
#
#
#         marker_e21660f21e2f700b61f18a9a86169999.bindPopup(popup_fcb21f9f749508d7da7825dd528a437c)
#         ;
#
#
#
#
#             var marker_571159647275614fae79174f0593972c = L.marker(

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2024-03-25 10:03:05
# Python Version: 3.10.11
# -----------------------------------
