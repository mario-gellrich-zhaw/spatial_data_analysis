# %% [markdown]
# # Getting all available Swiss petrol stations using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import json
import folium
import requests
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# u:\Lektionen\CAS_DAENG_FS2023\Raeumliche_Daten\05_Python_Basic_GIS_Functionality\Challenge

# %% [markdown]
# ## Overpass turbo query to get available petrol stations

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["amenity"="fuel"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to .json file
with open('petrol_stations.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = pd.json_normalize(data)
df.head()
# Out:
#    type       id        lat       lon tags.amenity  \
# 0  node   734402  46.690599  7.668189         fuel
# 1  node  1228781  46.878598  7.542326         fuel
# 2  node  5702030  46.680546  7.827412         fuel
# 3  node  5702071  46.683415  7.844559         fuel
# 4  node  8082505  46.683817  7.664427         fuel
#
#                                           tags.fixme tags.name tags.operator  \
# 0  Please check name and brand. Agip becomes Eni....      Agip          Agip
# 1                                                NaN       NaN            BP
# 2                                                NaN    Migrol           NaN
# 3                                                NaN      Avia          Avia
# 4                                                NaN       NaN           NaN
#
#   tags.brand tags.fuel:diesel  ... tags.fuel:octane_87  \
# 0        NaN              NaN  ...                 NaN
# 1         BP              yes  ...                 NaN
# 2        NaN              NaN  ...                 NaN
# 3       Avia              NaN  ...                 NaN
# 4        NaN              NaN  ...                 NaN
#
#   tags.payment:post_finance tags.payment:reka_card tags.covered  \
# 0                       NaN                    NaN          NaN
# 1                       NaN                    NaN          NaN
# 2                       NaN                    NaN          NaN
# 3                       NaN                    NaN          NaN
# 4                       NaN                    NaN          NaN
#
#   tags.payment:girocard tags.fuel:diesel_plus tags.construction  \
# 0                   NaN                   NaN               NaN
# 1                   NaN                   NaN               NaN
# 2                   NaN                   NaN               NaN
# 3                   NaN                   NaN               NaN
# 4                   NaN                   NaN               NaN
#
#   tags.payment:shell tags.dog tags.payment:hubrol_card
# 0                NaN      NaN                      NaN
# 1                NaN      NaN                      NaN
# 2                NaN      NaN                      NaN
# 3                NaN      NaN                      NaN
# 4                NaN      NaN                      NaN
#
# [5 rows x 185 columns]

# %% [markdown]
# ## Save data frame to a .csv file

# %%
# Write data frame to .csv - file
df.to_csv('petrol-stations.csv', index=False, sep=";", encoding='utf-8')

# %% [markdown]
# ## Use a pivot table to count the number of petrol stations per operator

# %%
# Create pivot table
tab = pd.pivot_table(df[['id', 'tags.name']], 
                       values=['id'], 
                       index=['tags.name'],
                       aggfunc='count')

# Sort pivot table
tab_sorted = tab.sort_values(by=['id'], ascending=False)
tab_sorted
# Out:
#                        id
# tags.name
# Avia                  155
# Agrola                137
# BP                    108
# Tamoil                 93
# Shell                  73
# ...                   ...
# Garage de la Prairie    1
# Garage de la Station    1
# Garage des 3 Sapins     1
# Garage des Alpes        1
# villoel                 1
#
# [818 rows x 1 columns]

# %% [markdown]
# ## Plot petrol stations on map

# %%
# Subset of petrol stations by brand
locations = df[["lat", 
                "lon", 
                "tags.brand", 
                "tags.shop"]].loc[df["tags.brand"].isin(['Migrol', 
                                                         'Agip', 
                                                         'Shell'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand tags.shop
# 9   47.686119  8.621418      Shell       NaN
# 20  47.495696  8.712981      Shell       NaN
# 24  47.381593  8.509545      Shell       NaN
# 29  47.381110  8.492148     Migrol       NaN
# 33  47.337432  8.530242      Shell       NaN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e40fe094672774efe83509923710a1b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e40fe094672774efe83509923710a1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e40fe094672774efe83509923710a1b = L.map(
#                 &quot;map_5e40fe094672774efe83509923710a1b&quot;,
#                 {
#                     center: [47.079419089181286, 8.170980993567252],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5e40fe094672774efe83509923710a1b);
#
#
#
#
#
#             var tile_layer_1daa28c818b69acacf435099cae9078c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e40fe094672774efe83509923710a1b);
#
#
#             var marker_974270d740239b1c44a8867b5bf2ba13 = L.marker(
#                 [47.686119, 8.621418],
#                 {}
#             ).addTo(map_5e40fe094672774efe83509923710a1b);
#
#
#         var popup_844084e180cbc32062c8182a979fe3c8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf24ef0eb364d943b33a3def666528de = $(`&lt;div id=&quot;html_cf24ef0eb364d943b33a3def666528de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_844084e180cbc32062c8182a979fe3c8.setContent(html_cf24ef0eb364d943b33a3def666528de);
#
#
#
#         marker_974270d740239b1c44a8867b5bf2ba13.bindPopup(popup_844084e180cbc32062c8182a979fe3c8)
#         ;
#
#
#
#
#             var marker_d526a6824e58c865b058fa5ad22932b0 = L.marker(
#                 [47.4956958, 8.7129812],
#                 {}
#             ).addTo(map_5e40fe094672774efe83509923710a1b);
#
#
#         var popup_386f837f15b2222c5e3b5d6c166a1fe6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d80ddbab6adbf95de14287216c8fd682 = $(`&lt;div id=&quot;html_d80ddbab6adbf95de14287216c8fd682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_386f837f15b2222c5e3b5d6c166a1fe6.setContent(html_d80ddbab6adbf95de14287216c8fd682);
#
#
#
#         marker_d526a6824e58c865b058fa5ad22932b0.bindPopup(popup_386f837f15b2222c5e3b5d6c166a1fe6)
#         ;
#
#
#
#
#             var marker_477bb23461bae8e1aa5fa886281703be = L.marker(
#                 [47.3815928, 8.5095448],
#                 {}
#             ).addTo(map_5e40fe094672774efe83509923710a1b);
#
#
#         var popup_7aeacbd7878392975be7ec33acd69a72 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d192be0bca63780fd52a5c558b64d38 = $(`&lt;div id=&quot;html_9d192be0bca63780fd52a5c558b64d38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_7aeacbd7878392975be7ec33acd69a72.setContent(html_9d192be0bca63780fd52a5c558b64d38);
#
#
#
#         marker_477bb23461bae8e1aa5fa886281703be.bindPopup(popup_7aeacbd7878392975be7ec33acd69a72)
#         ;
#
#
#
#
#             var marker_ecaaa1e72413d82e775405bd4ea942ed = L.marker(
#                 [47.3811098, 8.4921479],
#                 {}
#             ).addTo(map_5e40fe094672774efe83509923710a1b);
#
#
#         var popup_b9843fd6def7b5fd54c70d8106a58eed = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1b34a28e8b9224acdf3ceb9fad0f5178 = $(`&lt;div id=&quot;html_1b34a28e8b9224acdf3ceb9fad0f5178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migrol&lt;/div&gt;`)[0];
#                 popup_b9843fd6def7b5fd54c70d8106a58eed.setContent(html_1b34a28e8b9224acdf3ceb9fad0f5178);
#
#
#
#         marker_ecaaa1e72413d82e775405bd4ea942ed.bindPopup(popup_b9843fd6def7b5fd54c70d8106a58eed)
#         ;
#
#
#
#
#             var marker_62e6f9f917c3e657a8aa24465e51517b = L.marker(
#                 [47.3374315, 8.5302419],
#                 {}
#             ).addTo(map_5e40fe094672774efe83509923710a1b);
#
#
#         var popup_29b0fd10856b943ffe340b1f47b7d608 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_188e085cee6d31ab8c9fdbaf976fb577 = $(`&lt;div id=&quot;html_188e085cee6d31ab8c9fdbaf976fb577&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_29b0fd10856b943ffe340b1f47b7d608.setContent(html_188e085cee6d31ab8c9fdbaf976fb577);
#
#
#
#         marker_62e6f9f917c3e657a8aa24465e51517b.bindPopup(popup_29b0fd10856b943ffe340b1f47b7d608)
#         ;
#
#
#
#
#             var marker_17e127db136f3374087c3edf1dce0ee7 = L.marker(

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# NT
# Windows | 10
# Datetime: 2023-06-15 19:23:50
# Python Version: 3.10.11
# -----------------------------------
