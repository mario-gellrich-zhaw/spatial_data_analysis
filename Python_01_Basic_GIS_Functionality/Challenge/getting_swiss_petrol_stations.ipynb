# %% [markdown]
# # Getting all available Swiss petrol stations using the overpass Web API

# %% [markdown]
# ## Libraries and settings

# %%
# Libraries
import os
import json
import folium
import requests
import pandas as pd

# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Show current working directory
print(os.getcwd())
# Out:
# /workspaces/spatial_data_analysis/Python_Basic_GIS_Functionality/Challenge

# %% [markdown]
# ## Overpass turbo query to get available petrol stations

# %%
# Overpass API URL
url = 'http://overpass-api.de/api/interpreter'

# Overpass turbo query
query = f"""
        [out:json];
        area["ISO3166-1"="CH"][admin_level=2];
        node ["amenity"="fuel"](area);
        out;"""

# Web API request
r = requests.get(url, params={'data': query})
data = r.json()['elements']

# Save data to .json file
with open('petrol_stations.json', 'w') as json_file:
    json.dump(data, json_file)

# Store data in data frame
df = pd.json_normalize(data)
df.head()
# Out:
#    type       id        lat       lon tags.amenity  \
# 0  node   734402  46.690599  7.668189         fuel
# 1  node  1228781  46.878598  7.542326         fuel
# 2  node  5702030  46.680546  7.827412         fuel
# 3  node  5702071  46.683415  7.844559         fuel
# 4  node  8082505  46.683817  7.664427         fuel
#
#                                           tags.fixme tags.name tags.operator  \
# 0  Please check name and brand. Agip becomes Eni....      Agip          Agip
# 1                                                NaN       NaN            BP
# 2                                                NaN    Migrol           NaN
# 3                                                NaN      Avia          Avia
# 4                                                NaN       NaN           NaN
#
#   tags.brand tags.fuel:diesel  ... tags.fuel:Shell_V-Power  \
# 0        NaN              NaN  ...                     NaN
# 1         BP              yes  ...                     NaN
# 2        NaN              NaN  ...                     NaN
# 3       Avia              NaN  ...                     NaN
# 4        NaN              NaN  ...                     NaN
#
#   tags.payment:post_finance tags.covered tags.payment:girocard  \
# 0                       NaN          NaN                   NaN
# 1                       NaN          NaN                   NaN
# 2                       NaN          NaN                   NaN
# 3                       NaN          NaN                   NaN
# 4                       NaN          NaN                   NaN
#
#   tags.payment:vpay tags.fuel:diesel_plus tags.construction tags.dog  \
# 0               NaN                   NaN               NaN      NaN
# 1               NaN                   NaN               NaN      NaN
# 2               NaN                   NaN               NaN      NaN
# 3               NaN                   NaN               NaN      NaN
# 4               NaN                   NaN               NaN      NaN
#
#   tags.payment:hubrol_card  \
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
#
#   tags.payment:noten_euro_reka-pay_postcard_mastercard_avia-karte_visa_ec_karte_american_express_reka-karte_myone
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 192 columns]

# %% [markdown]
# ## Save data frame to a .csv file

# %%
# Write data frame to .csv - file
df.to_csv('petrol-stations.csv', index=False, sep=";", encoding='utf-8')

# %% [markdown]
# ## Use a pivot table to count the number of petrol stations per operator

# %%
# Create pivot table
tab = pd.pivot_table(df[['id', 'tags.name']], 
                       values=['id'], 
                       index=['tags.name'],
                       aggfunc='count')

# Sort pivot table
tab_sorted = tab.sort_values(by=['id'], ascending=False)
tab_sorted
# Out:
#                        id
# tags.name
# Avia                  157
# Agrola                143
# BP                    109
# Tamoil                 95
# Shell                  76
# ...                   ...
# Garage de la Prairie    1
# Garage de la Station    1
# Garage des 3 Sapins     1
# Garage des Alpes        1
# villoel                 1
#
# [816 rows x 1 columns]

# %% [markdown]
# ## Plot petrol stations on map

# %%
# Subset of petrol stations by brand
locations = df[["lat", 
                "lon", 
                "tags.brand", 
                "tags.shop"]].loc[df["tags.brand"].isin(['Migrol', 
                                                         'Agip', 
                                                         'Shell'])]
print(locations.head(5))

# Create map
map = folium.Map(location=[locations.lat.mean(), 
                           locations.lon.mean()], 
                 zoom_start=8, 
                 control_scale=True)

# Add maker symbols
for index, location_info in locations.iterrows():
    folium.Marker([location_info["lat"], 
                   location_info["lon"]], 
                   popup=location_info["tags.brand"]).add_to(map)

# Plot map
map
# Out:
#           lat       lon tags.brand tags.shop
# 9   47.686119  8.621418      Shell       NaN
# 20  47.495696  8.712981      Shell       NaN
# 24  47.381593  8.509545      Shell       NaN
# 29  47.381110  8.492148     Migrol       NaN
# 33  47.337432  8.530242      Shell       NaN
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d61ae7716a4f33533312be5ef451def {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d61ae7716a4f33533312be5ef451def&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d61ae7716a4f33533312be5ef451def = L.map(
#                 &quot;map_5d61ae7716a4f33533312be5ef451def&quot;,
#                 {
#                     center: [47.076009985964916, 8.153219148245613],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5d61ae7716a4f33533312be5ef451def);
#
#
#
#
#
#             var tile_layer_4321d51632a91bd592bc4192b3779b7c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#                 tile_layer_4321d51632a91bd592bc4192b3779b7c.addTo(map_5d61ae7716a4f33533312be5ef451def);
#
#             var marker_4ba57c8c5b22451d37cd439735d3c3c3 = L.marker(
#                 [47.686119, 8.621418],
#                 {}
#             ).addTo(map_5d61ae7716a4f33533312be5ef451def);
#
#
#         var popup_23f9480528a15e9fb5aa63452527f288 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bf8c4c312c51cf835f8f2737f7db449 = $(`&lt;div id=&quot;html_5bf8c4c312c51cf835f8f2737f7db449&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_23f9480528a15e9fb5aa63452527f288.setContent(html_5bf8c4c312c51cf835f8f2737f7db449);
#
#
#
#         marker_4ba57c8c5b22451d37cd439735d3c3c3.bindPopup(popup_23f9480528a15e9fb5aa63452527f288)
#         ;
#
#
#
#
#             var marker_798a45329b9a0cc650548dde55399ef5 = L.marker(
#                 [47.4956958, 8.7129812],
#                 {}
#             ).addTo(map_5d61ae7716a4f33533312be5ef451def);
#
#
#         var popup_e7e1fe0e9cdb03e45c2a114f44a048ad = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d3e06d9ffd4a124839cc403c8d28738 = $(`&lt;div id=&quot;html_9d3e06d9ffd4a124839cc403c8d28738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_e7e1fe0e9cdb03e45c2a114f44a048ad.setContent(html_9d3e06d9ffd4a124839cc403c8d28738);
#
#
#
#         marker_798a45329b9a0cc650548dde55399ef5.bindPopup(popup_e7e1fe0e9cdb03e45c2a114f44a048ad)
#         ;
#
#
#
#
#             var marker_6f7909aa32839068e76add8a2046430b = L.marker(
#                 [47.3815928, 8.5095448],
#                 {}
#             ).addTo(map_5d61ae7716a4f33533312be5ef451def);
#
#
#         var popup_f0d9151136b96b8fdd7070dcff81f8db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_57ce300c37e47358095f23ba35ed465a = $(`&lt;div id=&quot;html_57ce300c37e47358095f23ba35ed465a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_f0d9151136b96b8fdd7070dcff81f8db.setContent(html_57ce300c37e47358095f23ba35ed465a);
#
#
#
#         marker_6f7909aa32839068e76add8a2046430b.bindPopup(popup_f0d9151136b96b8fdd7070dcff81f8db)
#         ;
#
#
#
#
#             var marker_fd3e885fd95fd7edcc10150ed445d80a = L.marker(
#                 [47.3811098, 8.4921479],
#                 {}
#             ).addTo(map_5d61ae7716a4f33533312be5ef451def);
#
#
#         var popup_ad89676f284fa3f08b9d52165e0dd417 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_da2c96a5ee3a50500293f42874d78e2e = $(`&lt;div id=&quot;html_da2c96a5ee3a50500293f42874d78e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Migrol&lt;/div&gt;`)[0];
#                 popup_ad89676f284fa3f08b9d52165e0dd417.setContent(html_da2c96a5ee3a50500293f42874d78e2e);
#
#
#
#         marker_fd3e885fd95fd7edcc10150ed445d80a.bindPopup(popup_ad89676f284fa3f08b9d52165e0dd417)
#         ;
#
#
#
#
#             var marker_ec33da173dc87d075f010b72f9f8f499 = L.marker(
#                 [47.3374315, 8.5302419],
#                 {}
#             ).addTo(map_5d61ae7716a4f33533312be5ef451def);
#
#
#         var popup_416e193ff82018e3a6db699b0a07aa5f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_09014f9f04500f0947a1c2ecd11955a4 = $(`&lt;div id=&quot;html_09014f9f04500f0947a1c2ecd11955a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Shell&lt;/div&gt;`)[0];
#                 popup_416e193ff82018e3a6db699b0a07aa5f.setContent(html_09014f9f04500f0947a1c2ecd11955a4);
#
#
#
#         marker_ec33da173dc87d075f010b72f9f8f499.bindPopup(popup_416e193ff82018e3a6db699b0a07aa5f)
#         ;

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1015-azure
# Datetime: 2023-11-10 16:04:24
# Python Version: 3.10.13
# -----------------------------------
